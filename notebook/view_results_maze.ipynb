# %% [markdown]
# # 1D Maze Results Viewer
#
# Load saved `.pcellbundle` results from 1D maze analysis.
# Supports single or multi-session comparison.
#
# Interactive widgets require **Jupyter Lab**: `jupyter lab --no-browser`

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

from placecell.dataset import BasePlaceCellDataset
from placecell.event_overlay import (
    ProjectionConfig,
    ViewConfig,
    gather_events,
    plot_cross_session_occupancy,
    plot_event_overlay_2d,
    plot_event_overlay_3d,
    plot_zone_occupancy,
    select_top_place_cells,
)
from placecell.notebook import browse_units_1d, create_shuffle_browser_1d
from placecell.visualization import (
    plot_behavior_preview,
    plot_occupancy_preview_1d,
    plot_position_and_traces_1d,
    plot_session_summary,
    plot_speed_histogram,
)

plt.rcParams["pdf.fonttype"] = 42
plt.rcParams["ps.fonttype"] = 42
plt.rcParams["font.family"] = "Arial"

# %% [markdown]
# ## 1. Load Bundles

# %%
BUNDLE_PATHS = [
    Path("../tests/assets/regression_1d/reference.pcellbundle"),
]

datasets = {}
for bp in BUNDLE_PATHS:
    name = bp.stem.replace(".pcellbundle", "")
    ds = BasePlaceCellDataset.load_bundle(bp)
    datasets[name] = ds
    s = ds.summary()
    print(
        f"{name}: {s['n_total']} units, "
        f"{s['n_sig']} sig, {s['n_stable']} stable, "
        f"{s['n_place_cells']} place cells"
    )

# %% [markdown]
# ## 2. Cross-Session Summary

# %%
rows = []
for name, ds in datasets.items():
    rows.append({"dataset": name, **ds.summary()})
summary_df = pd.DataFrame(rows)
display(summary_df)

if len(datasets) > 1:
    plot_session_summary(summary_df)
    plt.show()

# %% [markdown]
# ---
# ## 3. Per-Session Inspection
#
# Change `SESSION` to switch between loaded sessions.

# %%
SESSION = list(datasets.keys())[0]
ds = datasets[SESSION]
p_thresh = ds.spatial_1d.p_value_threshold
print(f"Session: {SESSION}")
print(
    f"Config: bin_width_mm={ds.spatial_1d.bin_width_mm}, "
    f"spatial_sigma={ds.spatial_1d.spatial_sigma}, "
    f"n_shuffles={ds.spatial_1d.n_shuffles}, "
    f"p_threshold={p_thresh}"
)

# %% [markdown]
# ### 3a. Data Quality
#
# 2D trajectory density, speed distribution, and 1D occupancy with split-half comparison.

# %%
# 2D trajectory density + speed histogram (from raw x,y)
if ds.canonical is not None and ds.trajectory_1d_filtered is not None:
    plot_behavior_preview(
        ds.canonical, ds.trajectory_1d_filtered,
        ds.cfg.behavior.speed_threshold,
        speed_unit="mm/s",
        speed_column="speed_1d",
    )
    plt.show()

# 1D arm speed histogram
if ds.trajectory_1d is not None and "speed_1d" in ds.trajectory_1d.columns:
    n_filt = len(ds.trajectory_1d_filtered) if ds.trajectory_1d_filtered is not None else 0
    plot_speed_histogram(
        ds.trajectory_1d["speed_1d"].to_numpy(),
        ds.cfg.behavior.speed_threshold,
        speed_unit="mm/s",
        n_filtered=n_filt,
        n_total=len(ds.trajectory_1d),
    )
    plt.show()

# 1D occupancy with split halves
if ds.trajectory_1d_filtered is not None and ds.occupancy_time is not None:
    plot_occupancy_preview_1d(
        ds.trajectory_1d_filtered,
        ds.occupancy_time,
        ds.valid_mask,
        ds.edges_1d,
        trajectory_1d=ds.trajectory_1d,
        trajectory_1d_all=ds.trajectory_1d_all,
        arm_boundaries=ds.arm_boundaries,
        arm_labels=ds.effective_arm_order,
    )
    plt.show()

# %% [markdown]
# ### 3b. Place Cell Summary

# %%
place_cell_results = ds.place_cells()

table_rows = []
for uid, res in sorted(ds.unit_results.items()):
    is_sig = res.p_val < p_thresh
    is_stable = (
        not np.isnan(res.stability_p_val) and res.stability_p_val < p_thresh
    )
    stability_r = (
        round(res.stability_corr, 4) if np.isfinite(res.stability_corr) else np.nan
    )
    stability_p = (
        round(res.stability_p_val, 4) if np.isfinite(res.stability_p_val) else np.nan
    )
    table_rows.append({
        "unit_id": uid,
        "n_events": len(res.unit_data),
        "SI (bits/spike)": round(res.si, 4),
        "p_val": round(res.p_val, 4),
        "sig": is_sig,
        "stability_r": stability_r,
        "stability_p": stability_p,
        "stable": is_stable,
        "place_cell": is_sig and is_stable,
    })

unit_table = pd.DataFrame(table_rows).set_index("unit_id")
display(unit_table)

# %% [markdown]
# ### 3c. Neural Traces
#
# Speed over time and place cell traces (top 20 by SI).

# %%
if place_cell_results and ds.trajectory_1d is not None:
    plot_position_and_traces_1d(
        ds.trajectory_1d,
        place_cell_results,
        ds.edges_1d,
        behavior_fps=ds.data_cfg.behavior_fps,
        speed_threshold=ds.cfg.behavior.speed_threshold,
        trajectory_1d_filtered=ds.trajectory_1d_filtered,
        arm_boundaries=ds.arm_boundaries,
        arm_labels=ds.effective_arm_order,
    )
    plt.show()
else:
    print("No place cells or trajectory data available.")

# %% [markdown]
# ### 3d. Per-Unit Shuffle Browser
#
# Browse each unit's rate map, SI shuffle distribution, and stability shuffle distribution.
# Requires Jupyter Lab widgets.

# %%
# %matplotlib widget

fig_shuf, controls_shuf = create_shuffle_browser_1d(
    ds.unit_results,
    ds.edges_1d,
    p_value_threshold=p_thresh,
    arm_boundaries=ds.arm_boundaries,
    arm_labels=ds.effective_arm_order,
)
plt.show()
display(controls_shuf)

# %% [markdown]
# ### 3e. Interactive Unit Browser
#
# Browse all units with rate maps (1st half / 2nd half / full), shuffle histograms, and trace.
# Toggle between all units and place cells only. Requires Jupyter Lab widgets.

# %%
# %matplotlib widget

fig_units, controls_units = browse_units_1d(ds)
plt.show()
display(controls_units)

# %% [markdown]
# ### 3f. Cell event overlay
#
# Pick units (or auto-pick top-N place cells by SI) and plot their firing events on the 2D trajectory and the (x, y, time) 3D trajectory. Splits panels by direction when available.

# %%
CELL_IDS: list[int] = []
AUTO_TOP_N = 6
EVENT_PERCENTILE = 95.0
EVENT_ABS_MIN = 0.0
DOT_SIZE = 16
DOT_ALPHA = 1.0
SHOW_TRAJECTORY = True
SAVE_PDF = False
PDF_DIR = Path("overlay_pdfs")

view = ViewConfig(elev=15, azim=-60, box_aspect=(1, 1, 2))
projection = ProjectionConfig(z=None, dot_alpha=0.5, dot_size_frac=0.6)
GRAPH_PROJECTION_Z = None  # float=explicit z-plane, None=off

selected = list(CELL_IDS) if CELL_IDS else select_top_place_cells(ds, AUTO_TOP_N)
events_by_cell = gather_events(
    ds, selected,
    event_percentile=EVENT_PERCENTILE,
    event_abs_min=EVENT_ABS_MIN,
)
for uid, ev in events_by_cell.items():
    print(f"  unit {uid}: {len(ev)} events")


def _save(fig, stem):
    if SAVE_PDF:
        PDF_DIR.mkdir(parents=True, exist_ok=True)
        fig.savefig(PDF_DIR / f"{SESSION}_{stem}.pdf", bbox_inches="tight")
        print(f"  wrote {PDF_DIR / SESSION}_{stem}.pdf")


common_3d = dict(
    dot_size=DOT_SIZE,
    dot_alpha=DOT_ALPHA,
    view=view,
    projection=projection,
    graph_z=GRAPH_PROJECTION_Z,
    show_trajectory=SHOW_TRAJECTORY,
)

fig = plot_event_overlay_2d(ds, selected, events_by_cell=events_by_cell,
                            dot_alpha=DOT_ALPHA, title=f"{SESSION} — event overlay")
_save(fig, "2d")
plt.show()

fig = plot_event_overlay_3d(
    ds, selected, events_by_cell=events_by_cell,
    title=f"{SESSION} — event overlay 3D", **common_3d,
)
_save(fig, "3d")
plt.show()

fig = plot_event_overlay_3d(
    ds, selected, events_by_cell=events_by_cell,
    traversal_subset=True,
    title=f"{SESSION} — event overlay 3D (traversal subset)", **common_3d,
)
_save(fig, "3d_subset")
plt.show()

# Per-cell plots — one figure per selected unit.
for uid in selected:
    fig = plot_event_overlay_3d(
        ds, [uid], events_by_cell={uid: events_by_cell[uid]},
        traversal_subset=True,
        title=f"{SESSION} — cell {uid}", **common_3d,
    )
    _save(fig, f"3d_cell{uid}")
    plt.show()

# %% [markdown]
# ### 3g. Zone occupancy
#
# Per-session bar chart of arm and room occupancy (arms colored, rooms gray).

# %%
fig = plot_zone_occupancy(ds, proportion=False, title=f"{SESSION} — zone occupancy")
plt.show()
fig = plot_zone_occupancy(ds, proportion=True, title=f"{SESSION} — zone occupancy (proportion)")
plt.show()

# %% [markdown]
# ### 3h. Cross-session occupancy (mean ± SD)
#
# Aggregates proportional zone occupancy across all bundles loaded into `datasets`.

# %%
if len(datasets) >= 2:
    fig = plot_cross_session_occupancy(datasets)
    plt.show()
else:
    print('Load at least 2 sessions in BUNDLES to see cross-session stats.')
